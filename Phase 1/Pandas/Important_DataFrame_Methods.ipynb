# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# value counts
# counts how many times each value appears
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Sex"].value_counts(normalize=True) * 100
# percentage
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
# sort by index
df["Pclass"].value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
# unique
df["Embarked"].unique()

df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# nunique
df["Embarked"].nunique()
# Nan is not counted by default
# if u wanna count it
df["Embarked"].nunique(dropna=False)
# Out:
# 4

# %%
# is null
df["Age"].isnull()
# cheks weather value is missing or not
# count the missing age values
df["Age"].isnull().sum()

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# not null
df["Age"].notnull()

# count
df["Age"].notnull().sum()
# Out:
# np.int64(714)

# %%
# hasnans - checks weather a series contains any missing values
df["Age"].hasnans
# Out:
# True

# %%
# fillna() instead of deleting missing values
# replae them
df["Age"].fillna(0)

# replace with average age
df["Age"].fillna(df["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Embarked"].fillna("Unknown")
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# drop na
# remove missing values
df.dropna()

# this remove every row that contains even one missing value
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a = df.dropna(subset=["Age"])
a.describe()
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    object
#  4   Sex          714 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    object
#  9   Fare         714 non-null    float64
#  10  Cabin        185 non-null    object
#  11  Embarked     712 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 72.5+ KB

# %%
# duplicated
# cheks weather rows are duplicates
df.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# drop duplicate
# remove the duplicate
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# replace

df["Sex"].replace(
    {
        "male": "M",
        "female": "F"
    }
)
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: Sex, Length: 891, dtype: object

# %%
df["Embarked"].replace(
    {
        "S":"Southampton",
        "C":"Cherbourg",
        "Q":"Queenstown"
    }
)
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
# astype
# chnge the type
df["Pclass"].dtype

df["Pclass"] = df["Pclass"].astype(str)
df["Pclass"].dtype

df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: object

# %%
# copy
# mutable ha to .copy use karo
df2 = df.copy()
df2.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# sort values
# sorts the dataframe according to the col values

df.sort_values("Age")
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 803          804         1      3           Thomas, Master. Assad Alexander
# 755          756         1      2                 Hamalainen, Master. Viljo
# 644          645         1      3                    Baclini, Miss. Eugenie
# 469          470         1      3             Baclini, Miss. Helene Barbara
# 78            79         1      2             Caldwell, Master. Alden Gates
# ..           ...       ...    ...                                       ...
# 859          860         0      3                          Razi, Mr. Raihed
# 863          864         0      3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0      3               van Melkebeke, Mr. Philemon
# 878          879         0      3                        Laleff, Mr. Kristo
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# sort by mulitple columns
df.sort_values(
    ["Pclass", "Age"],
    ascending=[True, False]
)
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 630          631         1      1      Barkworth, Mr. Algernon Henry Wilson
# 96            97         0      1                 Goldschmidt, Mr. George B
# 493          494         0      1                   Artagaveytia, Mr. Ramon
# 745          746         0      1              Crosby, Capt. Edward Gifford
# 54            55         0      1            Ostby, Mr. Engelhart Cornelius
# ..           ...       ...    ...                                       ...
# 859          860         0      3                          Razi, Mr. Raihed
# 863          864         0      3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0      3               van Melkebeke, Mr. Philemon
# 878          879         0      3                        Laleff, Mr. Kristo
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# sort index
#  sort rows labels index
temp = df.sample(5)
temp
# Out:
#      PassengerId  Survived Pclass  \
# 402          403         0      3
# 796          797         1      1
# 516          517         1      2
# 535          536         1      2
# 567          568         0      3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 402                     Jussila, Miss. Mari Aina  female  21.0      1      0
# 796                  Leader, Dr. Alice (Farnham)  female  49.0      0      0
# 516                 Lemore, Mrs. (Amelia Milley)  female  34.0      0      0
# 535                       Hart, Miss. Eva Miriam  female   7.0      0      2
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
#
#            Ticket     Fare Cabin Embarked
# 402          4137   9.8250   NaN        S
# 796         17465  25.9292   D17        S
# 516    C.A. 34260  10.5000   F33        S
# 535  F.C.C. 13529  26.2500   NaN        S
# 567        349909  21.0750   NaN        S

# %%
temp.sort_index()
# Out:
#      PassengerId  Survived Pclass  \
# 402          403         0      3
# 516          517         1      2
# 535          536         1      2
# 567          568         0      3
# 796          797         1      1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 402                     Jussila, Miss. Mari Aina  female  21.0      1      0
# 516                 Lemore, Mrs. (Amelia Milley)  female  34.0      0      0
# 535                       Hart, Miss. Eva Miriam  female   7.0      0      2
# 567  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 796                  Leader, Dr. Alice (Farnham)  female  49.0      0      0
#
#            Ticket     Fare Cabin Embarked
# 402          4137   9.8250   NaN        S
# 516    C.A. 34260  10.5000   F33        S
# 535  F.C.C. 13529  26.2500   NaN        S
# 567        349909  21.0750   NaN        S
# 796         17465  25.9292   D17        S

# %%
# rank - rank values
df["Fare"].rank()
# Out:
# 0       77.0
# 1      789.0
# 2      232.5
# 3      748.0
# 4      264.0
#        ...
# 886    407.5
# 887    654.5
# 888    546.5
# 889    654.5
# 890    123.5
# Name: Fare, Length: 891, dtype: float64

# %%
df["FareRank"] = df["Fare"].rank(
    ascending= False
)
df.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FareRank
# 0      0         A/5 21171   7.2500   NaN        S     815.0
# 1      0          PC 17599  71.2833   C85        C     103.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     659.5
# 3      0            113803  53.1000  C123        S     144.0
# ...

# %%
# set index

df.set_index("PassengerId")
# Out:
#              Survived Pclass  \
# PassengerId
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df = df.set_index("PassengerId")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1480/521326244.py in <cell line: 0>()
# ----> 1 df = df.set_index("PassengerId")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['PassengerId'] are in the columns"

# %%
df
# Out:
#              Survived Pclass  \
# PassengerId
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# now the loc
df.loc[20]
# means that the persosn with the id 20
# Out:
# Survived                          1
# Pclass                            3
# Name        Masselmani, Mrs. Fatima
# Sex                          female
# Age                             NaN
# SibSp                             0
# Parch                             0
# Ticket                         2649
# Fare                          7.225
# Cabin                           NaN
# Embarked                          C
# FareRank                      842.5
# Name: 20, dtype: object

# %%
# reset index
df.reset_index(drop=True,inplace=True)
df
# Out:
#      index  PassengerId  Survived Pclass  \
# 0        0            1         0      3
# 1        1            2         1      1
# 2        2            3         1      3
# 3        3            4         1      1
# 4        4            5         0      3
# ..     ...          ...       ...    ...
# 886    886          887         0      2
# 887    887          888         1      1
# 888    888          889         0      3
# 889    889          890         1      1
# 890    890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# rename
df.rename(
    columns={
        "PassengerId": "ID"
    }
)
# Out:
#      index   ID  Survived Pclass  \
# 0        0    1         0      3
# 1        1    2         1      1
# 2        2    3         1      3
# 3        3    4         1      1
# 4        4    5         0      3
# ..     ...  ...       ...    ...
# 886    886  887         0      2
# 887    887  888         1      1
# 888    888  889         0      3
# 889    889  890         1      1
# 890    890  891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(
    columns={
        "PassengerId":"ID",
        "Pclass":"Class",
        "Fare":"TicketPrice"
    }
)
# Out:
#      index   ID  Survived Class  \
# 0        0    1         0     3
# 1        1    2         1     1
# 2        2    3         1     3
# 3        3    4         1     1
# 4        4    5         0     3
# ..     ...  ...       ...   ...
# 886    886  887         0     2
# 887    887  888         1     1
# 888    888  889         0     3
# 889    889  890         1     1
# 890    890  891         0     3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# rename axis
df = df.set_index("PassengerId")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1480/529158369.py in <cell line: 0>()
#       1 # rename axis
# ----> 2 df = df.set_index("PassengerId")
#       3 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['PassengerId'] are in the columns"

# %%
df
df.rename_axis("ID")
# rename the indexing
# Out:
#      index  Survived Pclass  \
# ID
# 1        0         0      3
# 2        1         1      1
# 3        2         1      3
# 4        3         1      1
# 5        4         0      3
# ..     ...       ...    ...
# 887    886         0      2
# 888    887         1      1
# 889    888         0      3
# 890    889         1      1
# 891    890         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# ID
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female  26.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# insert
# add a new col to a specific position
df.insert(0, "Country", "UK")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1480/2072629952.py in <cell line: 0>()
#       1 # insert
#       2 # add a new col to a specific position
# ----> 3 df.insert(0, "Country", "UK")
#       4 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#
# ValueError: cannot insert Country, already exists

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# drop
# remove rows or cols
df.drop("Cabin", axis=1)
# axis 1 means cols and axis 0 means rows
# reverse than numpy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# remove rows
df.drop(
    [0,1,2],
     axis=0
)
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %%
# pop
# remove a col and returns it
ticket = df.pop("Ticket")
ticket
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1480/3933122256.py in <cell line: 0>()
#       1 # pop
#       2 # remove a col and returns it
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# apply
# apply ur custom function to each value
df["Fare"].apply(lambda x: x*1.10)
# Out:
# 0       7.97500
# 1      78.41163
# 2       8.71750
# 3      58.41000
# 4       8.85500
#          ...
# 886    14.30000
# 887    33.00000
# 888    25.79500
# 889    33.00000
# 890     8.52500
# Name: Fare, Length: 891, dtype: float64

# %%
def age_group(age):
    if pd.isna(age):
        return "Unknown"
    elif age < 18:
        return "Child"
    elif age < 60:
        return "Adult"
    else:
        return "Senior"
df["AgeGroup"] = df["Age"].apply(age_group)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# isin
# cheks whether values belong to a given list
df[df["Pclass"].isin([1,3])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# corr
# show correlation between numeri columns
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# n largest
df.nlargest(5, "Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
#
#     AgeGroup
# 258    Adult
# 679    Adult
# 737    Adult
# 27     Adult
# 88     Adult

# %%
# n smallest , sort karo yar descending me and then us se n de do
df.nsmallest(5, "Age")
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked AgeGroup
# 803  0.42      0      1    2625   8.5167   NaN        C    Child
# 755  0.67      1      1  250649  14.5000   NaN        S    Child
# 469  0.75      2      1    2666  19.2583   NaN        C    Child
# 644  0.75      2      1    2666  19.2583   NaN        C    Child
# 78   0.83      0      2  248738  29.0000   NaN        S    Child

# %%
# clip
# limit values to a range
marks = pd.Series([20,30,40,50,10,30,40,100,1000,31212])
marks.clip(0, 100)
# Out:
# 0     20
# 1     30
# 2     40
# 3     50
# 4     10
# 5     30
# 6     40
# 7    100
# 8    100
# 9    100
# dtype: int64

# %%
# select dtypes
df.select_dtypes(include="number")
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df.select_dtypes(include="object")
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked AgeGroup
# 0           A/5 21171   NaN        S    Adult
# 1            PC 17599   C85        C    Adult
# 2    STON/O2. 3101282   NaN        S    Adult
# ...

# %%
numeric = df.select_dtypes(include="number")
numeric.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
# memory usage
df.memory_usage()
# show memory used by each column
# Out:
# Index           132
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# AgeGroup       7128
# dtype: int64

# %%
df.memory_usage().sum()
# Out:
# np.int64(92796)

# %%
# more detaild
# counts the actual memory used by string cols as well
df.memory_usage(deep=True).sum()
# Out:
# np.int64(340958)

# %%
# agg
df[["Age", "Fare"]].agg(["min","max", "mean"])
# Out:
#             Age        Fare
# min    0.420000    0.000000
# max   80.000000  512.329200
# mean  29.699118   32.204208

# %%
# mode
# returns the most freq
df.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked AgeGroup
# ...
